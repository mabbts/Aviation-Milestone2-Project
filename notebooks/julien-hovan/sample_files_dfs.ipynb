# %%
import pandas as pd

df_flight_data_metrics = pd.read_csv("/Users/mads/Desktop/Milestone_II/Aviation-Milestone2-Project/samples/flight_data_with_metrics.csv")
df_aggregate = pd.read_csv("/Users/mads/Desktop/Milestone_II/Aviation-Milestone2-Project/samples/aggregate_df.csv")
df_identification_data4 = pd.read_csv("/Users/mads/Desktop/Milestone_II/Aviation-Milestone2-Project/samples/identification_data4_sample.csv")
df_position_data4_sample = pd.read_csv("/Users/mads/Desktop/Milestone_II/Aviation-Milestone2-Project/samples/position_data4_sample.csv")
df_state_vectors_data4_sample = pd.read_csv("/Users/mads/Desktop/Milestone_II/Aviation-Milestone2-Project/samples/state_vectors_data4_sample.csv")
df_waypoint_df = pd.read_csv("/Users/mads/Desktop/Milestone_II/Aviation-Milestone2-Project/samples/waypoint_df.csv")
